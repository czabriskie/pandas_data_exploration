# %% [markdown]
# # Cleaning and Exploring a Dataset  with Pandas

# %% [markdown]
# ### Import Packages

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %% [markdown]
# ### Read in Data Set

# %%
hotel_data = pd.read_csv('data/hotel_bookings.csv')

# %% [markdown]
# ### Getting a glimpse of the data

# %% [markdown]
# First lets change some options so we can see all of our rows in jupyter notebook

# %% [markdown]
# If we want to let pandas show all the columns when using commands, we can set the option to do this with `pd.set_option('display.max_columns', None)`. To set this back to the default, we can reset this option with `pd.reset_option('max_columns;)` or set the display max to some other number `pd.set_option('display.max_columns', 5)`, but for now we will just show all the columns weth `pd.set_option('display.max_columns', None)`.

# %% [markdown]
# To get a quick look of the columns, we can just select the top 5 using the "head" function

# %%
hotel_data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
hotel_data.describe(include = 'all')
# Out:
#              hotel    is_canceled      lead_time  arrival_date_year  \
# count       119390  119390.000000  119390.000000      119390.000000
# unique           2            NaN            NaN                NaN
# top     City Hotel            NaN            NaN                NaN
# freq         79330            NaN            NaN                NaN
# mean           NaN       0.370416     104.011416        2016.156554
# std            NaN       0.482918     106.863097           0.707476
# min            NaN       0.000000       0.000000        2015.000000
# 25%            NaN       0.000000      18.000000        2016.000000
# 50%            NaN       0.000000      69.000000        2016.000000
# 75%            NaN       1.000000     160.000000        2017.000000
# max            NaN       1.000000     737.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count              119390             119390.000000
# ...

# %% [markdown]
# Looking through a dataset might spur other questions that you want to look into. For instance,
#
# 1. What is the proportion of cancels to non-cancels?
# 2. How common are these outliers of lead times above the 75 percentile?
# 3. Is there a difference in cancels based on the year, month, or day of month?
# 4. Are guests with more children and babies staying longer than guests that have only adult members of their party?
# 5. Do repeat guests cancel less often than other guests?
# 6. Is their a correlation between previous cancellatoins and a guest cancelling now? Is there something we can do with these guests to get them to stay more?
# 7. What are the occurences of people changing their booking? Is there something we can do to make sure guests get the booking right the first time?
# 8. What percent of our agents and companies have repeat bookings? What factors contribute to a company or agent booking with us more often? Can we influence that?
# 9. Could we use booking data to forecast how many guests we will have each day in the future? Could we leverage this model to know how much staffing we will need?
# 10. What hotel does the most business? Are any of these factors under our control?
# 11. Which market segments/distribution channels perform the best? Should we keep using all of the segments and channels?

# %% [markdown]
# ### Missing Data and Column Types

# %% [markdown]
# Sometimes Null values make sense and sometimes they don't. We will need to figure out what to do with these missing values on a case by case basis. The datatypes in a Pthon Dataframe can be
#
# - objects - mixed datatypes
# - int64 - integer number
# - float64 - decimal number
# - str - string of characters
# - category - categorical variable
# - bool - 0 or 1 True or False

# %%
# Find the number of NULL per column
len(hotel_data) - hotel_data.count()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %% [markdown]
# Do these datatypes make sense? Should we convert any to something else? Remember, we might want them as a specific data type depending on what we want to do with it (e.g. If we wanted to plot cancels per week number, we would want that to be an int. However, if we wanted to use that same data as a model variable we might want to make it a categorical variable).

# %%
hotel_data.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %% [markdown]
# The info function gives some additional information

# %%
hotel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# To change datatypes, we can just overwrite these values with the converted columns

# %%
hotel_data[['hotel', 
            'arrival_date_year', 
            'arrival_date_month',
            'meal', 'country', 
            'market_segment', 
            'distribution_channel']] = \
hotel_data[['hotel', 
            'arrival_date_year', 
            'arrival_date_month',
            'meal', 'country', 
            'market_segment', 
            'distribution_channel']].astype('category')

# %%
hotel_data.dtypes
# Out:
# hotel                             category
# is_canceled                          int64
# lead_time                            int64
# arrival_date_year                 category
# arrival_date_month                category
# arrival_date_week_number             int64
# arrival_date_day_of_month            int64
# stays_in_weekend_nights              int64
# stays_in_week_nights                 int64
# adults                               int64
# children                           float64
# babies                               int64
# meal                              category
# country                           category
# market_segment                    category
# distribution_channel              category
# is_repeated_guest                    int64
# previous_cancellations               int64
# previous_bookings_not_canceled       int64
# reserved_room_type                  object
# assigned_room_type                  object
# booking_changes                      int64
# ...

# %% [markdown]
# ### Now let's answer some of our previous questions

# %% [markdown]
# 1. What is the proportion of cancels to non-cancels?

# %% [markdown]
# There are several ways to subset a dataframe
# - `cancels = hotel_data.is_canceled`
# - `cancels = hotel_data['is_canceled']`
# - `cancels = hotel_data.loc[:, 'is_canceled']`
# - `cancels = hotel_data.iloc[:, 1]`

# %%
cancels = hotel_data.is_canceled

# %% [markdown]
# Now we can see how many cancels there are to non cancels

# %%
cancels.value_counts()
# Out:
# 0    75166
# 1    44224
# Name: is_canceled, dtype: int64

# %% [markdown]
# To get a proportion, we just need to divide each column by the total.

# %%
cancels.value_counts() / len(cancels)
# Out:
# 0    0.629584
# 1    0.370416
# Name: is_canceled, dtype: float64

# %% [markdown]
# Okay, so this is cool and all, but I'm assuming this has changed every year, what would be cool is if we had a year over year comparison of this

# %%
hotel_data[['arrival_date_year', 'is_canceled']].groupby(['arrival_date_year']).count()
# Out:
#                    is_canceled
# arrival_date_year
# 2015                     21996
# 2016                     56707
# 2017                     40687

# %% [markdown]
# This also brought up something new, why do we see a decrease of bookings from 2016 to 2017?

# %%
num_cancelations = hotel_data[['arrival_date_year', 'is_canceled']].groupby(['arrival_date_year']).sum() 
num_bookings = hotel_data[['arrival_date_year', 'is_canceled']].groupby(['arrival_date_year']).count() 

# Percent of Bookings that did not cancel
percent_cancelations = 1 - num_cancelations / num_bookings

percent_cancelations
# Out:
#                    is_canceled
# arrival_date_year
# 2015                  0.629842
# 2016                  0.641367
# 2017                  0.613021

# %% [markdown]
# Looks like the last year was our worst year in regards to keeping guest bookings booked. That combined with the decrease in overall bookings year over year is a pretty big red flag that something isn't working right. However, could this just be due to random chance?

# %%
percent_cancelations.reset_index(inplace = True)
percent_cancelations.rename(columns = \
                            {'arrival_date_year':'Year',
                             'is_canceled': 'pct_bookings_used'},
                           inplace = True)

percent_cancelations['pct_bookings_used'] = percent_cancelations['pct_bookings_used'] * 100

# %%
percent_cancelations.plot(kind = 'bar',
                          legend = False,
                          x = 'Year',
                          y = 'pct_bookings_used')
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# The above plot could do with some work, but more concerning is that it doesn't really show the story we want to tell, that we have decreased from last year. What other plot would be good here?
#
#
#
# Perhaps a YoY plot line plot by month would show this a bit better

# %%
# Create a new column that uses a month number instead of month name for easier plotting
conditions = [
    (hotel_data['arrival_date_month'] == 'January'),
    (hotel_data['arrival_date_month'] == 'February'),
    (hotel_data['arrival_date_month'] == 'March'),
    (hotel_data['arrival_date_month'] == 'April'),
    (hotel_data['arrival_date_month'] == 'May'),
    (hotel_data['arrival_date_month'] == 'June'),
    (hotel_data['arrival_date_month'] == 'July'),
    (hotel_data['arrival_date_month'] == 'August'),
    (hotel_data['arrival_date_month'] == 'September'),
    (hotel_data['arrival_date_month'] == 'October'),
    (hotel_data['arrival_date_month'] == 'November'),
    (hotel_data['arrival_date_month'] == 'December'),
]
choices = [x for x in range(1, 13)]
hotel_data['arrival_date_month_num'] = np.select(conditions, choices)

# %%
# Get the cancelations each year per month
num_month_cancelations = hotel_data[['arrival_date_year', 'arrival_date_month_num', 'is_canceled']].groupby(['arrival_date_year', 'arrival_date_month_num']).sum() 
num_month_bookings = hotel_data[['arrival_date_year', 'arrival_date_month_num', 'is_canceled']].groupby(['arrival_date_year', 'arrival_date_month_num']).count()

# reset index so we can get years for each column
num_month_cancelations.reset_index(inplace = True)
num_month_bookings.reset_index(inplace = True)

# %%
num_month_bookings
# Out:
#    arrival_date_year  arrival_date_month_num  is_canceled
# 0               2015                       1          NaN
# 1               2015                       2          NaN
# 2               2015                       3          NaN
# 3               2015                       4          NaN
# 4               2015                       5          NaN
# 5               2015                       6          NaN
# 6               2015                       7       2776.0
# 7               2015                       8       3889.0
# 8               2015                       9       5114.0
# 9               2015                      10       4957.0
# 10              2015                      11       2340.0
# 11              2015                      12       2920.0
# 12              2016                       1       2248.0
# 13              2016                       2       3891.0
# 14              2016                       3       4824.0
# ...

# %% [markdown]
# Seasonality could be a huge factor here in why there are more cancelations in one year over another. It looks like we don't have data for a lot of the months in 2015 and 2017

# %%
num_month_bookings['pct_bookings_used'] = num_month_cancelations.is_canceled / num_month_bookings.is_canceled * 100

# %%
num_month_bookings
# Out:
#    arrival_date_year  arrival_date_month_num  is_canceled  pct_bookings_used
# 0               2015                       1          NaN                NaN
# 1               2015                       2          NaN                NaN
# 2               2015                       3          NaN                NaN
# 3               2015                       4          NaN                NaN
# 4               2015                       5          NaN                NaN
# 5               2015                       6          NaN                NaN
# 6               2015                       7       2776.0          45.353026
# 7               2015                       8       3889.0          41.090255
# 8               2015                       9       5114.0          40.946422
# 9               2015                      10       4957.0          34.940488
# 10              2015                      11       2340.0          20.769231
# ...

# %%
# create new index for plotting 
# https://medium.com/@sciencelee/making-plots-with-the-pandas-groupby-ac492941af28
vals = num_month_bookings.groupby(['arrival_date_month_num', 'arrival_date_year'])['pct_bookings_used'].sum().unstack()
vals.replace(0, np.nan, inplace = True)

# %%
vals
# Out:
# arrival_date_year            2015       2016       2017
# arrival_date_month_num
# 1                             NaN  24.777580  33.958164
# 2                             NaN  34.361347  32.535312
# 3                             NaN  30.617745  33.641851
# 4                             NaN  37.969786  43.508214
# 5                             NaN  34.958014  43.750990
# 6                             NaN  39.606954  43.191075
# 7                       45.353026  32.786527  37.342368
# 8                       41.090255  36.045823  36.873096
# 9                       40.946422  37.486096        NaN
# 10                      34.940488  40.528776        NaN
# 11                      20.769231  36.731028        NaN
# 12                      33.321918  36.217617        NaN

# %%
vals.plot(kind = 'line')
# Out:
# <AxesSubplot:xlabel='arrival_date_month_num'>

# %% [markdown]
# Looking at the above plot, we can see that if we look at the data year over year, we are doing much better than we were in 2016 as far as keeping bookings. However, it is interesting how far we declined in 2015 over just a few months.
#
# The last question I had concerning booking was the difference between repeat guests and non-repeat guests in how much they cancel?

# %%
# Create new column that indicates if a guest is a repeat customer
total_repeats = hotel_data[['is_repeated_guest', 'is_canceled']].groupby('is_repeated_guest').count()
total_canceled_repeats = hotel_data[['is_repeated_guest', 'is_canceled']].groupby('is_repeated_guest').sum()

print(total_repeats)
print(total_canceled_repeats)
# Out:
#                    is_canceled
# is_repeated_guest
# 0                       115580
# 1                         3810
#                    is_canceled
# is_repeated_guest
# 0                        43672
# 1                          552

# %% [markdown]
# Not a lot of our bookings come from repeat clients. This seems odd are they not having a good experience, or is it because we only have a few years of data?

# %%
total_repeats = (1 - total_canceled_repeats / total_repeats) * 100
total_repeats.reset_index(inplace = True)
total_repeats.rename(columns = {'is_canceled': 'pct_kept_booking'},
                    inplace = True)

total_repeats
# Out:
#    is_repeated_guest  pct_kept_booking
# 0                  0         62.214916
# 1                  1         85.511811

# %% [markdown]
# It is interesting to see that the percentage of the repeat customers that keep their booking is significantly higher. This would be a good one to show in a plot I think

# %%
total_repeats['pct_kept_booking'].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# We could definitely do more with this. I wonder what cancelations looks like per each hotel and what the repeat customers who kept their booking looks like over time, but this is probably good enough to show someone.
